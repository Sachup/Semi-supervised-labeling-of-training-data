# %%
#This code is written by myself to crop the image from KITTI dataset for cropping the object of interest

# %%
import os
import uuid
import numpy as np
import matplotlib as plt
from PIL import Image

path = r"C:\Users\sachu\Desktop\My_Documents\label_2"  #Path of the labels of images from KITTI
car_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\cars_path"  #Path to which cars are saved
ped_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\Pedestrian_path"  #Path to which Pedestrian are saved
truck_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\Truck_path"   #Path to which Truck are saved
van_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\van_path"    #Path to which vans are saved
per_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\Person_sitting_path" #Path to which Person sitting are saved
misc_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\misc_path"   #Path to which miscallenious objects are saved
tram_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\Tram_path"   #Path to which Trams are saved
cyclist_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\Cyclist_path"  #Path to which Cyclicst are saved
for file in os.listdir(path):
    paths = os.path.join(path,file)
    with open(paths,'r') as f:
        listl = []
        img_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\training\image_2" #Path of KITTI image
        suffix = ".txt"
        file_new = file.removesuffix(suffix)
        file_new = file_new + ".png"
        img_path = os.path.join(img_path,file_new)
        im = Image.open(img_path)
        for line in f:
            strip_lines = line.strip()
            listli = strip_lines.split()
            print(listli)
            print(file)
            x = ['DontCare']
            if listli[0] == 'Car':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(car_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Pedestrian':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(ped_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Truck':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(truck_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Van':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(van_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Person_sitting':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(per_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Misc':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(misc_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Tram':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(tram_path, '{}.jpg'.format(uuid.uuid1())))
            elif listli[0] == 'Cyclist':
                l = listli[4]
                t = listli[5]
                r = listli[6]
                b = listli[7]
                im1 = im.crop((float(l),float(t),float(r),float(b)))
                im1.save(os.path.join(cyclist_path, '{}.jpg'.format(uuid.uuid1())))    
            else:
                break

# %%
#Code to refine the images got from above code

# %%
import uuid
import os
import numpy as np
import matplotlib as plt
import cv2
from PIL import Image
path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\Cropped_Images\Person_sitting_path"

for file in os.listdir(path):
    new_path = r"C:\Users\sachu\Desktop\My_Documents\Research_Project\Computer_Graphics\Kitti_dataset\Refined_crop_images\Person_Sitting_40_pixel"
    paths = os.path.join(path,file)
    im = Image.open(paths)
    w,h = im.size
    print(w)
    print(h)
    new_paths = os.path.join(new_path,file)
    if w > 40 or h > 40:
        im.save(new_paths)
